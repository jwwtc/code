# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from PIL import Image
from pymks import (generate_multiphase, plot_microstructures, PrimitiveTransformer,
                   TwoPointCorrelation,FlattenTransformer, PrimitiveBasis)
from pymks.stats import correlate
from pymks.tools import draw_microstructures
from sklearn.pipeline import Pipeline

# %%
from sklearn.decomposition import PCA

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
im = Image.open(r'C:\Users\mikep\Desktop\project\images\2.tif')
plt.figure()
plt.imshow(im)
plt.title("MICRESS microstructure of AA3104 CR")
plt.show()

# %%
#imarray = np.expand_dims(np.array(im), axis=0)

#fig = plot_microstructures(imarray)
imarray=np.array(im)
imarray.shape
# Out:
# (828, 834)

# %%
imarray2 = np.expand_dims(imarray, axis=0)
imarray2.shape
# Out:
# (1, 828, 834)

# %%
data = PrimitiveTransformer(n_state=2, min_=0.0, max_=1.0).transform(imarray2)
data.shape
# Out:
# (1, 828, 834, 2)

# %%
#model = Pipeline(steps=[
#    ('discretize', PrimitiveTransformer(n_state=2, min_=0.0, max_=1.0)),
#    ('correlations', TwoPointCorrelation(
#        periodic_boundary=True,
#        correlations=[[0,0], [1,1], [0,1]]
#                                        ).transform(data))
#])

#print(imarray.shape)
#x_stats = model.transform(imarray).persist()
#print(x_stats.shape)



#X = PrimitiveTransformer(n_state=2, min_=0.0, max_=1.0).transform(imarray)
#X.shape
#X_ = prim_basis.discretize(imarray)
#X_corr = correlate(X_, periodic_axes=[0, 1], basis=prim_basis)

# %%
plot_microstructures(
    data[0, :, :, 0],
    data[0, :, :, 0],
    titles=['First phase with ones', 'Second phase with ones'],
    cmap='gray',
    colorbar=False
)

# %%
auto_correlation = TwoPointCorrelation(
    periodic_boundary=True,
    cutoff=25,
    correlations=[(0,0)]
).transform(data)

# %%
auto_correlation.shape
# Out:
# (1, 51, 51, 1)

# %%
plot_microstructures(
    auto_correlation[0, :, :, 0],
    titles=['Correlation [0, 0]'],
    showticks=True
)

# %%
grain_sizes = [(30, 5), (10, 40), (15, 15), (5, 30)]
seeds = [10, 99, 4, 36]

data_synth = np.concatenate([
    generate_multiphase(shape=(10, 828, 834), grain_size=grain_size,
        volume_fraction=(0.8, 0.2),
        percent_variance=0.2,
        seed=seed
    )
    for grain_size, seed in zip(grain_sizes, seeds)
])

data_synth.shape
# Out:
# (40, 828, 834)

# %%
plot_microstructures(*data_synth[::10], cmap='gray', colorbar=False)

# %%
data_disc = PrimitiveTransformer(n_state=2, min_=0.0, max_=1.0).transform(data_synth)

# %%
data_disc.shape
# Out:
# (40, 828, 834, 2)

# %%
data_synth2=np.concatenate((data, data_disc))
data_synth2.shape
# Out:
# (41, 828, 834, 2)

# %%
data_corr = TwoPointCorrelation(
    periodic_boundary=True,
    cutoff=10,
    correlations=[(0, 0), (0, 1)]
).transform(data_synth2)

# %%
data_corr.shape
# Out:
# (41, 21, 21, 2)

# %%
plot_microstructures(
    data_corr[0, :, :, 0],
    data_corr[0, :, :, 1],
    titles=['1st Microstructure - Correlation [0, 0]', '1st Microstructure - Correlation [0, 1]'],
    showticks=True
)

# %%
pc_scores = PCA(
    svd_solver='full',
    n_components=3,
    random_state=10
).fit_transform(data_corr.reshape(40,-1))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-8118e49b1c61> in <module>
#       3     n_components=3,
#       4     random_state=10
# ----> 5 ).fit_transform(data_corr.reshape(40,-1))
#
# ~\anaconda3\envs\pymks\lib\site-packages\dask\array\core.py in reshape(self, merge_chunks, *shape)
#    1917         if len(shape) == 1 and not isinstance(shape[0], Number):
#    1918             shape = shape[0]
# -> 1919         return reshape(self, shape, merge_chunks=merge_chunks)
#    1920
#    1921     def topk(self, k, axis=-1, split_every=None):
#
# ~\anaconda3\envs\pymks\lib\site-packages\dask\array\reshape.py in reshape(x, shape, merge_chunks)
#     194         if len(shape) == 1 and x.ndim == 1:
#     195             return x
# --> 196         missing_size = sanitize_index(x.size / reduce(mul, known_sizes, 1))
#     197         shape = tuple(missing_size if s == -1 else s for s in shape)
#     198
#
# ~\anaconda3\envs\pymks\lib\site-packages\dask\array\slicing.py in sanitize_index(ind)
#      66         )
#      67     elif isinstance(ind, Number):
# ---> 68         return _sanitize_index_element(ind)
#      69     elif is_dask_collection(ind):
#      70         return ind
#
# ~\anaconda3\envs\pymks\lib\site-packages\dask\array\slicing.py in _sanitize_index_element(ind)
#      26         ind2 = int(ind)
#      27         if ind2 != ind:
# ---> 28             raise IndexError("Bad index.  Must be integer-like: %s" % ind)
#      29         else:
#      30             return ind2
#
# IndexError: Bad index.  Must be integer-like: 904.05

# %%
# %matplotlib notebook

# %%
#PYTEST_VALIDATE_IGNORE_OUTPUT
pc1, pc2, pc3, pc4 = np.split(pc_scores, 4)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(pc1[:,0], pc1[:,1], pc1[:,2], c='r', marker='o')
ax.scatter(pc2[:,0], pc2[:,1], pc2[:,2], c='g', marker='o')
ax.scatter(pc3[:,0], pc3[:,1], pc3[:,2], c='b', marker='o')
ax.scatter(pc4[:,0], pc4[:,1], pc4[:,2], c='k', marker='o')

ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_zlabel("PC3")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-4cb5b254a4b3> in <module>
#       1 #PYTEST_VALIDATE_IGNORE_OUTPUT
# ----> 2 pc1, pc2, pc3, pc4 = np.split(pc_scores, 4)
#       3
#       4 fig = plt.figure()
#       5 ax = fig.add_subplot(111, projection='3d')
#
# NameError: name 'pc_scores' is not defined
