# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
dfile = r'C:\Users\mikep\Desktop\project\data\train_hybrid_thin.npz'
images = np.load(dfile)["input_raw_data"]
images.shape
plt.ion()
plt.figure()
plt.axis('off')
plt.imshow(images[200].transpose((1,2,0)))
