# %%
import numpy as np
import GPy
import jedi
import pandas as pd
#configure plotting
#%matplotlib inline
#%config InlineBackend.figure_format = 'svg'
#import matplotlib;matplotlib.rcParams['figure.figsize'] = (8,5)
from matplotlib import pyplot as plt
#GPy.plotting.change_plotting_library('matplotlib')
from IPython.display import display

# %%
#import data

Xtrain = pd.read_csv(r'C:\Users\mikep\Desktop\project\data\final\Xtrain.csv')
Xtest = pd.read_csv(r'C:\Users\mikep\Desktop\project\data\final\Xtest.csv')
Ytrain = pd.read_csv(r'C:\Users\mikep\Desktop\project\data\final\Ytrain.csv')
Ytest = pd.read_csv(r'C:\Users\mikep\Desktop\project\data\final\Ytest.csv')

# %%
#further data preprocessing
#Xtrain
# Out:
#     Temperature  Duration
# 0      1118.625      1395
# 1      1105.875      3345
# 2      1093.125      7635
# 3      1080.375      4905
# 4      1067.625      8805
# 5      1054.875      1785
# 6      1042.125      2565
# 7      1029.375      6855
# 8      1016.625      4515
# 9      1003.875      6075
# 10      991.125      2955
# 11      978.375      5685
# 12      965.625      5295
# 13      952.875      2175
# 14      940.125      4125
# 15      927.375      3735
# 16      914.625      6465
# 17      901.875      8415
# 18      889.125      7245
# 19      876.375      8025

# %%
# product of kernels

k1 = GPy.kern.RBF(1, 1, 1, active_dims=[0]) # works on the first column of X, Temperature
k2 = GPy.kern.RBF(1, 3, 3, active_dims=[1]) # works on the second column of X, Duration

#k3 = GPy.kern.RBF(1, 1, 1)
#k4 = GPy.kern.RBF(1, 3, 3)

k_prod = k1 * k2
#k_prod_b = k3 * k4

k_prod.plot()
#k_prod_b.plot()
# Out:
#  C:\Users\mikep\anaconda3\lib\site-packages\GPy\plotting\matplot_dep\plot_definitions.py:184: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
# {'covariance': [<matplotlib.contour.QuadContourSet at 0x1eb80ba6700>]}

# %%
# sum of kernels

k5 = GPy.kern.RBF(1, 1, 2, active_dims=[0])
k6 = GPy.kern.RBF(1, 3, 3, active_dims=[1])

k_add = k5 + k6
k_add.plot()
# Out:
# {'covariance': [<matplotlib.contour.QuadContourSet at 0x1eb80c5aac0>]}

# %% [markdown]
# Note that the kernels that have been added are pythonic in that the objects remain linked: changing parameters of an add kernel changes those of the constituent parts, and vice versa.

# %%
#plotting function for kernel

def plot_sample(k):
    xx, yy = np.mgrid[-3:3:30j, -3:3:30j]
    X = np.vstack((xx.flatten(), yy.flatten())).T
    K = k.K(X)
    s = np.random.multivariate_normal(np.zeros(X.shape[0]), K)
    #plt.contourf(xx, yy, s.reshape(*xx.shape), cmap=plt.cm.hot)
    plt.imshow(s.reshape(*xx.shape), interpolation='nearest')
    plt.colorbar()

plot_sample(k_prod)

# %%
# regression models

m_prod = GPy.models.GPRegression(Xtrain, Ytrain, k_prod)
m_add = GPy.models.GPRegression(Xtrain, Ytrain, k_add)

display(m_prod, m_add)
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 2664.581468556071<br>
# <b>Number of Parameters</b>: 5<br>
# <b>Number of Optimization Parameters</b>: 5<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# ...

# %%
GP.plot = gpy_plot.gp_plots.plot

fig_prod = m_prod.plot()
#GPy.plotting.show(fig_prod, filename='basic_gp_regression_notebook')

ax = m_prod.plot(plot_limits=[-15, 15])

dataplot = ax['dataplot'][0] 
#dataplot.figure.savefig(r'C:\Users\mikep\Desktop\gp-test.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 GP.plot = gpy_plot.gp_plots.plot
#       3 fig_prod = m_prod.plot()
#       4 #GPy.plotting.show(fig_prod, filename='basic_gp_regression_notebook')
#
# NameError: name 'gpy_plot' is not defined

# %%
#fig_add = m_add.plot()

# %%
# optimization

m_prod.optimize(messages=True, max_f_eval = 1000)
m_add.optimize(messages=True, max_f_eval = 1000)

# %%
#fig_prod_opt = m_prod.plot()

# %%
#fig_add_opt = m_add.plot()

# %%
#plot the kernels
_ = k_prod.plot(ax=plt.gca())

# %%
_ = k_add.plot(ax=plt.gca())

# %% [markdown]
# The flag `ARD=True` in the definition of the `Matern` kernel specifies that we want one lengthscale parameter per dimension (ie the GP is not isotropic). Note that for 2-d plotting, only the mean is shown.

# %% [markdown]
# ## Plotting slices
# To see the uncertaintly associated with the above predictions, we can plot slices through the surface. this is done by passing the optional `fixed_inputs` argument to the plot function. `fixed_inputs` is a list of tuples containing which of the inputs to fix, and to which value.
#
# To get horixontal slices of the above GP, we'll fix second (index 1) input to -1, 0, and 1.5:

# %%
slices = [-1, 0, 1.5]
figure = GPy.plotting.plotting_library().figure(3, 1)
                        #shared_xaxes=True,
                        #subplot_titles=('slice at -1', 
                                        #'slice at 0', 
                                        #'slice at 1.5', 
                                        #)
                                    #)
for i, y in zip(range(3), slices):
    canvas = m.plot(figure=figure, fixed_inputs=[(1,y)], row=(i+1), plot_data=False)
#GPy.plotting.show(canvas, filename='basic_gp_regression_notebook_slicing')

# %% [markdown]
# The data look strange here: we're seeing slices of the GP, but all the data are displayed, even though they might not be close to the current slice.

# %% [markdown]
# To get vertical slices, we simply fixed the other input. We'll turn the display of data off also:

# %%
slices = [-1, 0, 1.5]
figure = GPy.plotting.plotting_library().figure(3, 1) 
                        #subplot_titles=('slice at -1', 
                                        #'slice at 0', 
                                        #'slice at 1.5', 
                                        #)
                            #)
for i, y in zip(range(3), slices):
    canvas = m.plot(figure=figure, fixed_inputs=[(0,y)], row=(i+1), plot_data=False)
#GPy.plotting.show(canvas, filename='basic_gp_regression_notebook_slicing_vertical')

# %% [markdown]
# You can find a host of other plotting options in the `m.plot` docstring. `Type m.plot?<enter>` to see.
