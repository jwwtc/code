# %%
#Packages
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from smt.sampling_methods import LHS
import pandas as pd
# Out:
# Bad key text.latex.preview in file C:\Users\mikep\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 123 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file C:\Users\mikep\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 155 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# ...

# %%
#Sampling --- Temperature / Duration
limits = np.array([[870, 1125], [1200, 9000]])
sampling = LHS(xlimits=limits)

num = 20
x = sampling(num)

Xtrain = x[0:10]
Xtest = x[10:20]

print(x)
print(x.shape, Xtrain.shape, Xtest.shape)
# Out:
# [[1067.625 4125.   ]
#  [1093.125 5295.   ]
#  [ 965.625 2565.   ]
#  [ 978.375 6075.   ]
#  [1016.625 7245.   ]
#  [ 876.375 8025.   ]
#  [1105.875 7635.   ]
#  [1003.875 6465.   ]
#  [1118.625 2175.   ]
#  [ 940.125 3345.   ]
#  [ 914.625 5685.   ]
#  [ 952.875 1785.   ]
#  [1080.375 1395.   ]
#  [ 991.125 8805.   ]
#  [1029.375 3735.   ]
#  [ 901.875 2955.   ]
#  [1042.125 4515.   ]
#  [ 927.375 8415.   ]
#  [ 889.125 4905.   ]
#  [1054.875 6855.   ]]
# (20, 2) (10, 2) (10, 2)
# numpy.ndarray

# %%
#Figure
plt.rcParams["figure.figsize"] = (15, 12)

plt.plot(x[:, 0], x[:, 1], "o", c='black', markersize=10, markeredgecolor='black')
#plt.plot(Xtest[:, 0], Xtest[:, 1], "o", c='black', markersize=10, markeredgecolor='black')

plt.title('Latin Hypercube Sampling', fontsize=30, pad=20)

plt.xlabel("Temperature (Kelvin)", fontsize=25, labelpad=20)
plt.ylabel("Annealing Time (seconds)", fontsize=25, labelpad=20)

label_size = 20
plt.rcParams['xtick.labelsize'] = label_size
plt.rcParams['ytick.labelsize'] = label_size
plt.tick_params(axis="both",size=15, direction="in", pad=8)

plt.grid(which='major', axis='both', linestyle='--', linewidth=1)
plt.savefig(r'C:\Users\mikep\Desktop\thesis\figures\sampling_nocsv.png', dpi=200)
plt.show()

# %%
#Save csv
df1 = pd.DataFrame(x)
df1.to_csv(r'C:\Users\mikep\Desktop\project\code\sampling\samples.csv')

# %%
df2 = pd.read_csv(r'C:\Users\mikep\Desktop\project\code\sampling\chart.csv')
samples_csv = df2.to_numpy()
samples_csv
# Out:
# array([[1118.625, 1395.   ],
#        [1105.875, 3345.   ],
#        [1093.125, 7635.   ],
#        [1080.375, 4905.   ],
#        [1067.625, 8805.   ],
#        [1054.875, 1785.   ],
#        [1042.125, 2565.   ],
#        [1029.375, 6855.   ],
#        [1016.625, 4515.   ],
#        [1003.875, 6075.   ],
#        [ 991.125, 2955.   ],
#        [ 978.375, 5685.   ],
#        [ 965.625, 5295.   ],
#        [ 952.875, 2175.   ],
#        [ 940.125, 4125.   ],
#        [ 927.375, 3735.   ],
#        [ 914.625, 6465.   ],
#        [ 901.875, 8415.   ],
#        [ 889.125, 7245.   ],
#        [ 876.375, 8025.   ]])

# %%
#Figure2
plt.rcParams["figure.figsize"] = (15, 12)

plt.plot(samples_csv[:, 0], samples_csv[:, 1], "o", c='black', markersize=10, markeredgecolor='black')

plt.title('Latin Hypercube Sampling', fontsize=30, pad=20)

plt.xlabel("Temperature (Kelvin)", fontsize=25, labelpad=20)
plt.ylabel("Annealing Time (seconds)", fontsize=25, labelpad=20)

label_size = 20
plt.rcParams['xtick.labelsize'] = label_size
plt.rcParams['ytick.labelsize'] = label_size
plt.tick_params(axis="both",size=15, direction="in", pad=8)

plt.grid(which='major', axis='both', linestyle='--', linewidth=1)
plt.savefig(r'C:\Users\mikep\Desktop\thesis\figures\sampling.png', dpi=200)
plt.show()
